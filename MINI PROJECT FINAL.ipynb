# %%
from tkinter import *
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk
import mysql.connector as sqlt
'''

con=sqlt.connect(host='localhost',user='root',password='atishay123456')
cur=con.cursor()
cur=con.cursor(buffered=True)
if(con):
    print("connection successful")
else:
    print("connection unsuccessful")
cur.execute("create database if not exists bank")
cur.execute("use bank")
cur.execute("create table if not exists account(acnum bigint,acname char(50),phone varchar(50),address char(50),email char(50),gender char(50),amount float)")
'''
fwin=Tk()
fwin.title("Bank Management Project")
fwin.state('zoomed')
fwin.configure(bg='sky blue')
fwin.resizable(width=False,height=False)
#p1 = ImageTk.PhotoImage(Image.open(r"C:\Users\DELL\Desktop\coins.jpg"))  
#fwin.iconphoto(False, p1) 

header_frm=Frame(fwin)
header_frm.configure(bg='blue')
header_frm.place(x=0,y=0,relwidth=1,relheight=0.15)


title_lbl=Label(header_frm,text="Bank of Delhi",font=("Courier New",35,"bold"),bg='blue',fg="white")
title_lbl.place(relx=0.40,rely=0.2)

#file1=ImageTk.PhotoImage(file=r"C:\Users\DELL\Desktop\bank.jpg")
#rm_lbl=Label(header_frm,image=file1)
#rm_lbl.place(relx=0.36,rely=0.1)

def main_body():
    def clearit():
        user_entry.delete(0,"end")
        pwd_entry.delete(0,"end")
        user_entry.focus()
    def login():
        uid=user_entry.get()
        pwd=pwd_entry.get()
        if(len(uid)==0 or len(pwd)==0):
            messagebox.showwarning("validation","Username/ password  can't be left empty")
        else:
            if(uid=="123" and pwd=="123"):#"Isha"and pwd=="5699isha"
                messagebox.showinfo("welcome admin","Login Successfully")
                frm.destroy()
                login_body()
            else:
                messagebox.showerror("validation","Invalid username / password")
                
    frm=Frame(fwin)
    frm.configure(bg='sky blue')
    frm.place(x=0,rely=0.1,relwidth=1,relheight=0.90)

    samp_lbl=Label(frm,text="Enter the details to LOGIN !",font=("Courier New",30,),bg="sky blue",fg="Midnight blue")
    samp_lbl.place(relx=0.3,rely=0.1)
    
    user_lbl=Label(frm,text="Username",font=("Goudy Old Style",30,'bold'),bg="sky blue",fg='Midnight blue')
    user_lbl.place(relx=0.3,rely=0.25)
    user_entry=Entry(frm,font=("Goudy Old Style",20),bd=6)
    user_entry.place(relx=0.5,rely=0.25)
                                             
    pwd_lbl=Label(frm,text="Password",font=("Goudy Old Style",30,'bold'),bg="sky blue",fg='Midnight blue')
    pwd_lbl.place(relx=0.3,rely=0.35)
    pwd_entry=Entry(frm,font=("Goudy Old Style",20),bd=6,show="*")
    pwd_entry.place(relx=0.5,rely=0.35)
    
    login_btn=Button(frm,text="Login",font=("Lucida Fax",20),bd=6,width=15,command=login)
    login_btn.place(relx=0.3,rely=0.50)
    
    login_clear=Button(frm,text="Clear",font=("Lucida Fax",20),bd=6,width=15,command=clearit)
    login_clear.place(relx=0.50,rely=0.50)


def login_body():
    def log_out():
        messagebox.showinfo("Thank you for using this application","Logout Successfully")
        frm.destroy()
        main_body()
        
    def add_account():
        frm.destroy()
        add_account_record()
        
    def find_account():
        frm.destroy()
        find_account_body()
        
    def modify_account():
        frm.destroy()
        modify_account_body()
        
    def del_account():
        frm.destroy()
        delete_account_body()
        
    frm=Frame(fwin)
    frm.configure(bg='sky blue')
    frm.place(x=0,rely=0.25,relwidth=1,relheight=0.75)
        
    side_frm=Frame(fwin,highlightbackground="white",highlightthickness="2")
    side_frm.configure(bg='grey')
    side_frm.place(x=1100,y=125,relwidth=1,relheight=0.90)

    heading=Label(frm,text="The bank that builds better relationships",font=("Lucida Calligraphy",30),bg="sky blue",fg="Midnight blue")
    heading.place(relx=0.1,rely=0)

    welcome_lbl=Label(frm,text="  Welcome Isha  ",font=("Lucida Fax",30),bg="blue",fg="white")
    welcome_lbl.place(relx=0.25,rely=0.3)

    logout=Label(frm,text="Click to Logout",font=("Lucida Fax",30),bg="sky blue",fg="Midnight blue")
    logout.place(relx=0.1,rely=0.57)
         
    logout_btn=Button(frm,text="Logout",font=("Lucida Fax",20),bd=6,width=15,command=log_out)
    logout_btn.place(relx=0.4,rely=0.55)

    addaccount_btn=Button(side_frm,text="Add Account",font=("Lucida Fax",20),bd=6,width=15,command=add_account)
    addaccount_btn.place(relx=0.05,rely=0.1)
     
    search_btn=Button(side_frm,text="Search Account",font=("Lucida Fax",20),bd=6,width=15,command=find_account)
    search_btn.place(relx=0.05,rely=0.3)

    deposit_btn=Button(side_frm,text="Modify Account",font=("Lucida Fax",20),bd=6,width=15,command=modify_account)
    deposit_btn.place(relx=0.05,rely=0.5)

    delete_student_btn=Button(side_frm,text="Delete Account",font=("Lucida Fax",20),bd=6,width=15,command=del_account)
    delete_student_btn.place(relx=0.05,rely=0.7)

def add_account_record():
    messagebox.showinfo('','Welcome To Add Account  Module')
    def log_out():
        messagebox.showinfo("Thank you for using application","Logout Successfully")
        frm.destroy()
        main_body()
        
    def back():
        frm.destroy()
        login_body()

    def add_accountdb():
        acnum=acc_num_entry.get()
        acname=acc_name_entry.get()
        phone=acc_phone_entry.get()
        address=acc_address_entry.get()
        email=acc_email_entry.get()
        gender=acc_gender_entry.get()
        amount=acc_amount_entry.get()
        
        
        con=sqlt.connect(host='localhost',user='root',password='ishu1810',database="bank")
        cursor=con.cursor()
        try:
            cursor.execute("insert into account (acnum,acname,phone,address,email,gender,amount)values(%s,%s,%s,%s,%s,%s,%s)",(acnum,acname,phone,address,email,gender,amount))
            con.commit()
            messagebox.showinfo("Information","Registration Successfully")
            frm.destroy()
            add_account_record()
            
            acc_num_entry.delete(0,"end")
            acc_name_entry.delete(0,"end")
            acc_phone_entry.delete(0,"end")
            acc_address_entry.delete(0,"end")
            acc_email_entry.delete(0,"end")
            acc_gender_entry.delete(0,"end")
            acc_amount_entry.delete(0,"end")
            
        except Exception as e:
            messagebox.showerror(' ',str(e))
        con.commit()
        con.close()
        
    frm=Frame(fwin)
    frm.configure(bg='sky blue')
    frm.place(x=0,rely=0.25,relwidth=1,relheight=0.75)

    side_frm=Frame(fwin,highlightbackground="white",highlightthickness="2")
    side_frm.configure(bg='grey')
    side_frm.place(x=1100,y=125,relwidth=1,relheight=0.90)

    heading_a=Label(frm,text="Enter the Details and Press Save:",font=("Courier New",20,'bold'),bg="sky blue",fg="Midnight blue")
    heading_a.place(relx=0.05,rely=0)

    logout_btn=Button(side_frm,text="Logout",font=("Lucida Fax",20),width=15,bd=6,command=log_out)
    logout_btn.place(relx=0.05,rely=0.2)

    back_btn=Button(side_frm,text="Back",font=("Lucida Fax",20),bd=6,width=15,command=back)
    back_btn.place(relx=0.05,rely=0.3)
    
    con=sqlt.connect(host='localhost',user='root',password='ishu1810',database="bank")
    cursor=con.cursor()
    cursor.execute("select max(acnum) from account")
    mid=cursor.fetchone()
    if mid[0]==None:
        acdata=707220220008301
    else:
        acdata=mid[0]+1
    con.close()
    
    acc_num=Label(frm,text="Account Number:",font=("Goudy Old Style",30,'bold'),bg="sky blue",fg='Midnight blue')
    acc_num.place(relx=0.05,rely=0.1)
    acc_num_entry=Entry(frm,font=("Goudy Old Style",20),bd=6)
    acc_num_entry.place(relx=0.3,rely=0.1)
    acc_num_entry.insert(0,acdata)

    acc_name=Label(frm,text="Account Name:",font=("Goudy Old Style",30,'bold'),bg="sky blue",fg='Midnight blue')
    acc_name.place(relx=0.05,rely=0.2)
    acc_name_entry=Entry(frm,font=("Goudy Old Style",20),bd=6)
    acc_name_entry.place(relx=0.3,rely=0.2)
    acc_name_entry.focus()
    
    acc_phone=Label(frm,text="Contact Number:",font=("Goudy Old Style",30,'bold'),bg="sky blue",fg='Midnight blue')
    acc_phone.place(relx=0.05,rely=0.3)
    acc_phone_entry=Entry(frm,font=("Goudy Old Style",20),bd=6)
    acc_phone_entry.place(relx=0.3,rely=0.3)
    acc_phone_entry.focus()

    acc_address=Label(frm,text="Residence:",font=("Goudy Old Style",30,'bold'),bg="sky blue",fg='Midnight blue')
    acc_address.place(relx=0.05,rely=0.4)
    acc_address_entry=Entry(frm,font=("Goudy Old Style",20),bd=6)
    acc_address_entry.place(relx=0.3,rely=0.4)
    acc_address_entry.focus()


    acc_amount=Label(frm,text="Account Amount:",font=("Goudy Old Style",30,'bold'),bg="sky blue",fg='Midnight blue')
    acc_amount.place(relx=0.05,rely=0.7)
    acc_amount_entry=Entry(frm,font=("Goudy Old Style",20),bd=6)
    acc_amount_entry.place(relx=0.3,rely=0.7)
    acc_amount_entry.focus()
    

    acc_email=Label(frm,text="E-mail:",font=("Goudy Old Style",30,'bold'),bg="sky blue",fg='Midnight blue')
    acc_email.place(relx=0.05,rely=0.5)
    acc_email_entry=Entry(frm,font=("Goudy Old Style",20),bd=6)
    acc_email_entry.place(relx=0.3,rely=0.5)
    acc_email_entry.focus()
    
    acc_gender=Label(frm,text="Gender:",font=("Goudy Old Style",30,'bold'),bg="sky blue",fg='Midnight blue')
    acc_gender.place(relx=0.05,rely=0.6)
    acc_gender_entry=Entry(frm,font=("Goudy Old Style",20),bd=6)
    acc_gender_entry.place(relx=0.3,rely=0.6)
    acc_gender_entry.focus()

    
    save_btn=Button(side_frm,text="Save",font=("Lucida Fax",20),bd=6,width=15,command=add_accountdb)
    save_btn.place(relx=0.05,rely=0.4)


def find_account_body():
    messagebox.showinfo('','Welcome To Account Search Module')
    def log_out():
        messagebox.showinfo("Thank you for using application","Logout Successfully")
        frm.destroy()
        main_body()
        
    def back():
        frm.destroy()
        login_body()

    def search_acc():
        acc_num=acc_num_entry.get()
        con=sqlt.connect(host='localhost',user='root',password='ishu1810',database="bank")
        cursor=con.cursor()
        cursor.execute("select * from account where acnum=%s",(acc_num,))
        row=cursor.fetchone()
        if row==None:
            messagebox.showerror("Error","student Id does not exist")
        else:
            acc_num_entry.delete(0,"end")
            acc_name_entry.delete(0,"end")
            acc_phone_entry.delete(0,"end")
            acc_address_entry.delete(0,"end")
            acc_email_entry.delete(0,"end")
            acc_gender_entry.delete(0,"end")
            acc_amount_entry.delete(0,"end")
            
            acc_num_entry.insert(0,row[0])
            acc_name_entry.insert(0,row[1])
            acc_phone_entry.insert(0,row[2])
            acc_address_entry.insert(0,row[3])
            acc_email_entry.insert(0,row[4])
            acc_gender_entry.insert(0,row[5])
            acc_amount_entry.insert(0,row[6])
                
    frm=Frame(fwin)
    frm.configure(bg='sky blue')
    frm.place(x=0,rely=0.25,relwidth=1,relheight=0.75)

    side_frm=Frame(fwin)
    side_frm.configure(bg='grey')
    side_frm.place(x=1100,y=125,relwidth=1,relheight=0.90)

    heading_s=Label(frm,text="Enter the Account Number to Search the Account:",font=("Courier New",20,'bold'),bg="sky blue",fg="Midnight blue")
    heading_s.place(relx=0.05,rely=0)

    logout_btn=Button(side_frm,text="Logout",font=("Lucida Fax",20),width=15,bd=6,command=log_out)
    logout_btn.place(relx=0.05,rely=0.2)

    back_btn=Button(side_frm,text="Back",font=("Lucida Fax",20),bd=6,width=15,command=back)
    back_btn.place(relx=0.05,rely=0.3)
    
    acc_num=Label(frm,text="Account Number:",font=("Goudy Old Style",30,'bold'),bg="sky blue",fg='Midnight blue')
    acc_num.place(relx=0.05,rely=0.1)
    acc_num_entry=Entry(frm,font=("Goudy Old Style",20),bd=6)
    acc_num_entry.place(relx=0.3,rely=0.1)

    acc_name=Label(frm,text="Account Name:",font=("Goudy Old Style",30,'bold'),bg="sky blue",fg='Midnight blue')
    acc_name.place(relx=0.05,rely=0.2)
    acc_name_entry=Entry(frm,font=("Goudy Old Style",20),bd=6)
    acc_name_entry.place(relx=0.3,rely=0.2)
    
    acc_phone=Label(frm,text="Contact Number:",font=("Goudy Old Style",30,'bold'),bg="sky blue",fg='Midnight blue')
    acc_phone.place(relx=0.05,rely=0.3)
    acc_phone_entry=Entry(frm,font=("Goudy Old Style",20),bd=6)
    acc_phone_entry.place(relx=0.3,rely=0.3)

    acc_address=Label(frm,text="Residence:",font=("Goudy Old Style",30,'bold'),bg="sky blue",fg='Midnight blue')
    acc_address.place(relx=0.05,rely=0.4)
    acc_address_entry=Entry(frm,font=("Goudy Old Style",20),bd=6)
    acc_address_entry.place(relx=0.3,rely=0.4)


    acc_amount=Label(frm,text="Account Amount:",font=("Goudy Old Style",30,'bold'),bg="sky blue",fg='Midnight blue')
    acc_amount.place(relx=0.05,rely=0.7)
    acc_amount_entry=Entry(frm,font=("Goudy Old Style",20),bd=6)
    acc_amount_entry.place(relx=0.3,rely=0.7)
    

    acc_email=Label(frm,text="E-mail:",font=("Goudy Old Style",30,'bold'),bg="sky blue",fg='Midnight blue')
    acc_email.place(relx=0.05,rely=0.5)
    acc_email_entry=Entry(frm,font=("Goudy Old Style",20),bd=6)
    acc_email_entry.place(relx=0.3,rely=0.5)
    
    acc_gender=Label(frm,text="Gender:",font=("Goudy Old Style",30,'bold'),bg="sky blue",fg='Midnight blue')
    acc_gender.place(relx=0.05,rely=0.6)
    acc_gender_entry=Entry(frm,font=("Goudy Old Style",20),bd=6)
    acc_gender_entry.place(relx=0.3,rely=0.6)
    
    search_btn=Button(side_frm,text="Search Account",font=("Lucida Fax",20),bd=6,width=15,command=search_acc)
    search_btn.place(relx=0.05,rely=0.4)

def modify_account_body():
    messagebox.showinfo('','Welcome To Account Modify Module')

    def log_out():
        messagebox.showinfo("Thank you for using application","Logout Successfully")
        frm.destroy()
        main_body()

    def back():
        frm.destroy()
        login_body()

    def modify_account_db():
        new_acnum=acc_num_entry.get()
        new_acname=acc_name_entry.get()
        new_phone=acc_phone_entry.get()
        new_address=acc_address_entry.get()
        new_email=acc_email_entry.get()
        new_gender=acc_gender_entry.get()
        new_amount=acc_amount_entry.get()
        
       
        con=sqlt.connect(host='localhost',user='root',password='ishu1810',database="bank")
        cursor=con.cursor()
        
        query="update account set acname='"+new_acname +"' where acnum="+ new_acnum
        cursor.execute(query)
        query="update account set phone='"+ new_phone +"' where acnum="+ new_acnum
        cursor.execute(query)
        
        query="update account set address='"+ new_address +"' where acnum="+ new_acnum
        cursor.execute(query)
        
        query="update account set email='"+ new_email +"' where acnum="+ new_acnum
        cursor.execute(query)
        
        query="update account set gender='"+ new_gender +"' where acnum="+ new_acnum
        cursor.execute(query)
        
        query="update account set amount='"+ new_amount +"' where acnum="+ new_acnum
        cursor.execute(query)
        con.commit()
        con.close()
        messagebox.showinfo("Data Modified","Modification Successfully")
    
    def search_acc():
        acc_num=acc_num_entry.get()
        con=sqlt.connect(host='localhost',user='root',password='ishu1810',database="bank")
        cursor=con.cursor()
        cursor.execute("select * from account where acnum=%s",(acc_num,))
        row=cursor.fetchone()
        if row==None:
            messagebox.showerror("Error","account Id does not exist")
        else:
            acc_num_entry.delete(0,"end")
            acc_name_entry.delete(0,"end")
            acc_phone_entry.delete(0,"end")
            acc_address_entry.delete(0,"end")
            acc_email_entry.delete(0,"end")
            acc_gender_entry.delete(0,"end")
            acc_amount_entry.delete(0,"end")
            
            acc_num_entry.insert(0,row[0])
            acc_name_entry.insert(0,row[1])
            acc_phone_entry.insert(0,row[2])
            acc_address_entry.insert(0,row[3])
            acc_email_entry.insert(0,row[4])
            acc_gender_entry.insert(0,row[5])
            acc_amount_entry.insert(0,row[6])
        
    frm=Frame(fwin)
    frm.configure(bg='sky blue')
    frm.place(x=0,rely=0.25,relwidth=1,relheight=0.75)

    side_frm=Frame(fwin,highlightbackground="white",highlightthickness="2")
    side_frm.configure(bg='grey')
    side_frm.place(x=1100,y=125,relwidth=1,relheight=0.90)

    heading_m=Label(frm,text="Enter the Account Number to Search & Modify the Account:",font=("Courier New",20,'bold'),bg="sky blue",fg="Midnight blue")
    heading_m.place(relx=0.05,rely=0)

    logout_btn=Button(side_frm,text="Logout",font=("Lucida Fax",20),width=15,bd=6,command=log_out)
    logout_btn.place(relx=0.05,rely=0.2)

    back_btn=Button(side_frm,text="Back",font=("Lucida Fax",20),bd=6,width=15,command=back)
    back_btn.place(relx=0.05,rely=0.3)
    
    acc_num=Label(frm,text="Account Number:",font=("Goudy Old Style",30,'bold'),bg="sky blue",fg='Midnight blue')
    acc_num.place(relx=0.05,rely=0.1)
    acc_num_entry=Entry(frm,font=("Goudy Old Style",20),bd=6)
    acc_num_entry.place(relx=0.3,rely=0.1)

    acc_name=Label(frm,text="Account Name:",font=("Goudy Old Style",30,'bold'),bg="sky blue",fg='Midnight blue')
    acc_name.place(relx=0.05,rely=0.2)
    acc_name_entry=Entry(frm,font=("Goudy Old Style",20),bd=6)
    acc_name_entry.place(relx=0.3,rely=0.2)
    
    acc_phone=Label(frm,text="Contact Number:",font=("Goudy Old Style",30,'bold'),bg="sky blue",fg='Midnight blue')
    acc_phone.place(relx=0.05,rely=0.3)
    acc_phone_entry=Entry(frm,font=("Goudy Old Style",20),bd=6)
    acc_phone_entry.place(relx=0.3,rely=0.3)

    acc_address=Label(frm,text="Residence:",font=("Goudy Old Style",30,'bold'),bg="sky blue",fg='Midnight blue')
    acc_address.place(relx=0.05,rely=0.4)
    acc_address_entry=Entry(frm,font=("Goudy Old Style",20),bd=6)
    acc_address_entry.place(relx=0.3,rely=0.4)


    acc_amount=Label(frm,text="Account Amount:",font=("Goudy Old Style",30,'bold'),bg="sky blue",fg='Midnight blue')
    acc_amount.place(relx=0.05,rely=0.7)
    acc_amount_entry=Entry(frm,font=("Goudy Old Style",20),bd=6)
    acc_amount_entry.place(relx=0.3,rely=0.7)
    

    acc_email=Label(frm,text="E-mail:",font=("Goudy Old Style",30,'bold'),bg="sky blue",fg='Midnight blue')
    acc_email.place(relx=0.05,rely=0.5)
    acc_email_entry=Entry(frm,font=("Goudy Old Style",20),bd=6)
    acc_email_entry.place(relx=0.3,rely=0.5)
    
    acc_gender=Label(frm,text="Gender:",font=("Goudy Old Style",30,'bold'),bg="sky blue",fg='Midnight blue')
    acc_gender.place(relx=0.05,rely=0.6)
    acc_gender_entry=Entry(frm,font=("Goudy Old Style",20),bd=6)
    acc_gender_entry.place(relx=0.3,rely=0.6)
    
    search_btn=Button(side_frm,text="Search Account",font=("Lucida Fax",20),bd=6,width=15,command=search_acc)
    search_btn.place(relx=0.05,rely=0.4)
       
    modify_btn=Button(side_frm,text="Modify Details ",font=("Lucida Fax",20),bd=6,width=15,command=modify_account_db)
    modify_btn.place(relx=0.05,rely=0.5)


def delete_account_body():
    messagebox.showinfo('','Welcome To Account Delete Module')
    def log_out():
        messagebox.showinfo("Thank you for using application","Logout Successfully")
        frm.destroy()
        main_body()

    def back():
        frm.destroy()
        login_body()

    def del_account_db():
        acnum=acc_num_entry.get()
        con=sqlt.connect(host='localhost',user='root',password='ishu1810',database="bank")
        cursor=con.cursor()
        try:
            cursor.execute("delete from account where acnum=%s",(acnum,))
            con.commit()
            messagebox.showinfo("Info","Account Record Deleted Successfully ")
        except Exception as e:
            messagebox.showerror(' ',str(e))
        con.close()
        
    frm=Frame(fwin)
    frm.configure(bg='sky blue')
    frm.place(x=0,rely=0.25,relwidth=1,relheight=0.75)

    side_frm=Frame(fwin,highlightbackground="white",highlightthickness="2")
    side_frm.configure(bg='grey')
    side_frm.place(x=1100,y=125,relwidth=1,relheight=0.90)

    heading_d=Label(frm,text="Enter the Account Number to Delete the Account:",font=("Courier New",20,'bold'),bg="sky blue",fg="Midnight blue")
    heading_d.place(relx=0.1,rely=0.2)

    logout_btn=Button(side_frm,text="Logout",font=("Lucida Fax",20),width=15,bd=6,command=log_out)
    logout_btn.place(relx=0.05,rely=0.3)

    back_btn=Button(side_frm,text="Back",font=("Lucida Fax",20),bd=6,width=15,command=back)
    back_btn.place(relx=0.05,rely=0.4)
    
    acc_num=Label(frm,text="Account Number:",font=("Goudy Old Style",30,'bold'),bg="sky blue",fg='Midnight blue')
    acc_num.place(relx=0.1,rely=0.3)
    acc_num_entry=Entry(frm,font=("Goudy Old Style",20),bd=6)
    acc_num_entry.place(relx=0.4,rely=0.3)

    delete_btn=Button(side_frm,text="Delete account",font=("Lucida Fax",20),width=15,bd=6,command=del_account_db)
    delete_btn.place(relx=0.05,rely=0.5)
             
main_body()
fwin.mainloop()
# Out:
# Exception in Tkinter callback
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\site-packages\mysql\connector\connection_cext.py", line 268, in _open_connection
#     self._cmysql.connect(**cnx_kwargs)
# _mysql_connector.MySQLInterfaceError: Access denied for user 'root'@'localhost' (using password: YES)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\DELL\AppData\Local\Temp\ipykernel_24740\1831247184.py", line 491, in del_account_db
#     con=sqlt.connect(host='localhost',user='root',password='ishu1810',database="bank")
#   File "C:\Users\DELL\anaconda3\lib\site-packages\mysql\connector\pooling.py", line 286, in connect
#     return CMySQLConnection(*args, **kwargs)
# ...
